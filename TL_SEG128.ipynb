# %% [markdown]
# # CRIAR E TREINAR A REDE NEURAL - USAR GPU

# %%
# Link do Colab com o Drive
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf  # Biblioteca para criar a rede neural
from tensorflow import keras
from keras import callbacks, layers, regularizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt  # Para visualizar imagens
import numpy as np  # Para manipulação de arrays
import os  # Para trabalhar com diretórios
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
import cv2
import kagglehub
import numpy as np

# Importação necessária para o modelo pré-treinado
from tensorflow.keras.applications import EfficientNetB0

# 1. Download e definição do caminho
path = kagglehub.dataset_download("mohammadhossein77/brain-tumors-dataset")
print("Caminho original do KaggleHub:", path)

# 2. Coleta Inteligente de Imagens e Rótulos
image_paths = []
labels_raw = []

# Formatos de imagem aceitos
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp')

# Percorre todas as pastas e subpastas
for root, dirs, files in os.walk(path):
    for file in files:
        if file.lower().endswith(valid_extensions):
            img_path = os.path.join(root, file)
            # A "classe" será o nome da pasta onde a imagem está
            label_name = os.path.basename(root)

            image_paths.append(img_path)
            labels_raw.append(label_name)

# 3. Mapeamento de Classes para Números
class_names_list = sorted(list(set(labels_raw)))
num_classes = len(class_names_list)
class_to_label = {name: i for i, name in enumerate(class_names_list)}

# Converter os nomes das classes para os índices numéricos
labels = np.array([class_to_label[name] for name in labels_raw])
image_paths = np.array(image_paths)

print(f"\nTotal de imagens encontradas: {len(image_paths)}")
print(f"Classes identificadas: {class_names_list}")
for name, idx in class_to_label.items():
    count = list(labels_raw).count(name)
    print(f" - {name}: {count} imagens")
# Out:
# Mounted at /content/drive
# Using Colab cache for faster access to the 'brain-tumors-dataset' dataset.
# Caminho original do KaggleHub: /kaggle/input/brain-tumors-dataset
#
# Total de imagens encontradas: 21672
# Classes identificadas: ['Normal', 'glioma_tumor', 'meningioma_tumor', 'pituitary_tumor']
#  - Normal: 3066 imagens
#  - glioma_tumor: 6307 imagens
#  - meningioma_tumor: 6391 imagens
#  - pituitary_tumor: 5908 imagens

# %%
# --- DOWNLOAD E CONFIGURAÇÃO DO DATASET ---
# Baixa a versão mais recente do dataset do Kaggle
path = kagglehub.dataset_download("mohammadhossein77/brain-tumors-dataset")
print("Path to dataset files:", path)

IMAGE_SIZE = (128, 128)
AUTOTUNE = tf.data.AUTOTUNE

# --- FUNÇÃO DE SEGMENTAÇÃO (OpenCV) ---

def segment_image_cv(image_tensor):
    img = image_tensor.numpy().astype(np.uint8)
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Se a imagem vier com shape (1, 128, 128, 3), remove o 1
    if len(img.shape) == 4:
        img = np.squeeze(img, axis=0)

    # Conversão para tons de cinza
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    blurred = cv2.GaussianBlur(gray, (7, 7), 0)

    # Otsu Thresholding
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Aplica a máscara
    segmented = cv2.bitwise_and(img, img, mask=thresh)

    return segmented.astype(np.float32)

# --- COLETA RECURSIVA DE IMAGENS E RÓTULOS ---
image_paths = []
labels_raw = []
valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp')

# Caminha por todas as subpastas do Kaggle
for root, dirs, files in os.walk(path):
    for file in files:
        if file.lower().endswith(valid_extensions):
            img_path = os.path.join(root, file)
            label_name = os.path.basename(root)
            image_paths.append(img_path)
            labels_raw.append(label_name)

# Mapeamento de classes
class_names_list = sorted(list(set(labels_raw)))
num_classes = len(class_names_list)
class_to_label = {name: i for i, name in enumerate(class_names_list)}
labels = np.array([class_to_label[name] for name in labels_raw])
image_paths = np.array(image_paths)

# --- DIVISÃO DOS DADOS ---
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.2, random_state=42, stratify=labels
)
val_paths, test_paths, val_labels, test_labels = train_test_split(
    test_paths, test_labels, test_size=0.5, random_state=42, stratify=test_labels
)

print(f"Total de imagens: {len(image_paths)}")
print(f"Classes: {class_names_list}")

# --- DATASET E AUGMENTATION ---
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.02)
], name="data_augmentation")

def create_tf_dataset(image_paths, labels, num_classes, batch_size, shuffle=False, augment=False):
    def load_image(image_path, label):
        img = tf.io.read_file(image_path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, IMAGE_SIZE)

        # Aplicação da Segmentação via py_function
        [img,] = tf.py_function(segment_image_cv, [img], [tf.float32])
        img.set_shape((IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

        label = tf.one_hot(label, num_classes)
        return img, label

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=1000)

    dataset = dataset.map(load_image, num_parallel_calls=AUTOTUNE)

    if augment:
         dataset = dataset.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)

    dataset = dataset.batch(batch_size)
    dataset = dataset.cache().prefetch(buffer_size=AUTOTUNE)
    return dataset

train_dataset = create_tf_dataset(train_paths, train_labels, num_classes, batch_size=16, shuffle=True, augment=True)
val_dataset = create_tf_dataset(val_paths, val_labels, num_classes, batch_size=16)
test_dataset = create_tf_dataset(test_paths, test_labels, num_classes, batch_size=16)

# --- MODELO, TREINO E AVALIAÇÃO ---
def create_model(num_classes):
    # 1. Carrega a base pré-treinada (sem o topo/classificador)
    # include_top=False remove a camada final de classificação (que é para 1000 classes)
    # weights='imagenet' carrega os pesos aprendidos
    base_model = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
    )

    # 2. Congelar a Base
    # Impede que os pesos do modelo sejam atualizados na primeira fase do treino
    base_model.trainable = False

    # 3. Construir o Modelo Completo
    inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

    # A EfficientNet espera valores 0-255, então NÃO usa Rescaling(1./255)
    # Se fosse VGG16 ou ResNet, precisaria de pré-processamento específico.

    # O parâmetro training=False é crucial para manter a BatchNormalization em modo de inferência
    x = base_model(inputs, training=False)

    # Reconstruindo o cabeçalho (Head) de classificação
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x) # Ajuda a estabilizar o treino
    x = layers.Dropout(0.4)(x)         # Reduz overfitting

    # Camada densa opcional para aprender características mais específicas antes da saída
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.35)(x)

    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs, name="EfficientNet_TransferLearning")

    # 4. Compilar
    model.compile(
        loss="categorical_crossentropy",
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        metrics=["accuracy", tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
    )

    return model

model = create_model(num_classes)

# Early Stopping e Learning Rate para o treinamento
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=0.00001
)

# Callback para salvar o melhor modelo
model_checkpoint_callback = ModelCheckpoint(
    filepath='/content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# -------------------------------------------------------------------------------------------
# ESSA PARTE É CASO PARE O TREINAMENTO NO MEIO
def finalizar_e_plotar(model, history, test_dataset):
    print("\nIniciando plotagem e avaliação...")

    # Parte 1: Gráficos de Treino
    if history is not None and hasattr(history, 'history'):
        # Plotagem dos resultados do treinamento
        plt.figure(figsize=(12, 5))

        # Plotar Acurácia
        plt.subplot(1, 2, 1)
        plt.plot(history.history['accuracy'], label='treino_acurácia')
        plt.plot(history.history['val_accuracy'], label='val_acurácia')
        plt.xlabel('Época')
        plt.ylabel('Acurácia')
        plt.title('Acurácia no Treinamento e Validação')
        plt.legend(loc='lower right')

        # Plotar Loss
        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='treino_loss')
        plt.plot(history.history['val_loss'], label='val_loss')
        plt.xlabel('Época')
        plt.ylabel('Loss')
        plt.title('Loss no Treinamento e Validação')
        plt.legend(loc='upper right')
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    else:
        print("Histórico de treinamento incompleto ou inexistente. Pulando gráficos de evolução.")

    # Parte 2: Avaliação do Modelo (Funciona mesmo se parar no meio, pois usa o estado atual do model)
    print("\nAvaliação do modelo final no conjunto de teste:")
    try:
        loss, accuracy, precision, recall = model.evaluate(test_dataset)

        print(f"Loss no teste: {loss:.4f}")
        print(f"Acurácia no teste: {accuracy:.4f}")
        print(f"Precisão no teste: {precision:.4f}")
        print(f"Recall no teste: {recall:.4f}")

        # Calcular F1-score
        y_pred_probs = model.predict(test_dataset)
        y_pred = np.argmax(y_pred_probs, axis=1)

        y_true = []
        for images, labels in test_dataset.unbatch():
            y_true.append(np.argmax(labels.numpy()))
        y_true = np.array(y_true)

        f1 = f1_score(y_true, y_pred, average='weighted') # Usar 'weighted' para multiclasse
        print(f"F1-score no teste: {f1:.4f}")

    except Exception as e:
        print(f"Erro ao avaliar o modelo: {e}")

# -------------------------------------------------------------------------------------------
# BLOCO DE TREINAMENTO COM FINE-TUNING
history = None

try:
    print("--- FASE 1: Treinamento com Base Congelada (Transfer Learning) ---")
    print("Pressione Stop/Ctrl+C para interromper a qualquer momento.")

    # 1. Primeiro Treino (O modelo aprende o básico das novas classes)
    history = model.fit(
        train_dataset,
        epochs=50,
        validation_data=val_dataset,
        callbacks=[early_stopping, reduce_lr, model_checkpoint_callback]
    )

    # ---------------- COMEÇO DO FINE TUNING ----------------
    # Este código só roda se a Fase 1 terminar sem erros ou interrupções
    print("\n--- FASE 2: Iniciando Fine-Tuning (Ajuste Fino) ---")

    # A. Descongelar a base (EfficientNet)
    # No modelo funcional criado, a camada [0] é o Input e a [1] é a EfficientNet
    model.layers[1].trainable = True

    # B. Recompilar com taxa de aprendizado MUITO BAIXA (Crucial!)
    # Usa 1e-5 (0.00001) para ajustar os pesos suavemente sem destruir o conhecimento
    model.compile(
        loss="categorical_crossentropy",
        optimizer=keras.optimizers.Adam(learning_rate=1e-5),
        metrics=["accuracy", tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
    )

    # C. Treinar novamente (Fase de Refinamento)
    # Adiciona mais épocas ao total (ex: 50 iniciais + 20 de refino)
    total_epochs = 50 + 20

    # Pega a última época do treino anterior para continuar a contagem correta
    initial_epoch = history.epoch[-1] + 1

    history_fine = model.fit(
        train_dataset,
        epochs=total_epochs,
        initial_epoch=initial_epoch, # Começa da época 51
        validation_data=val_dataset,
        callbacks=[early_stopping, reduce_lr, model_checkpoint_callback]
    )

    # D. Atualiza o histórico para o gráfico final mostrar o resultado do refino
    history = history_fine
# ---------------- FIM DO FINE TUNING ----------------

except KeyboardInterrupt:
    print("\n\nTreinamento interrompido MANUALMENTE pelo usuário!")
    print("Gerando gráficos com o estado atual do modelo...")

finally:
    # 1. Primeiro roda a sua função de avaliação normal
    finalizar_e_plotar(model, history, test_dataset)

    # Salva as listas de teste para não perder a referência das imagens
    np.save('/content/drive/MyDrive/Projeto/test_paths.npy', test_paths)
    np.save('/content/drive/MyDrive/Projeto/test_labels.npy', test_labels)

    print("Pronto para gerar matriz de confusão")
# Out:
# Using Colab cache for faster access to the 'brain-tumors-dataset' dataset.
# Path to dataset files: /kaggle/input/brain-tumors-dataset
# Total de imagens: 21672
# Classes: ['Normal', 'glioma_tumor', 'meningioma_tumor', 'pituitary_tumor']
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# --- FASE 1: Treinamento com Base Congelada (Transfer Learning) ---
# Pressione Stop/Ctrl+C para interromper a qualquer momento.
# Epoch 1/50
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6259 - loss: 1.0667 - precision: 0.6520 - recall: 0.5885
# Epoch 1: val_loss improved from inf to 0.45876, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 179s 138ms/step - accuracy: 0.6260 - loss: 1.0665 - precision: 0.6520 - recall: 0.5886 - val_accuracy: 0.8251 - val_loss: 0.4588 - val_precision: 0.8683 - val_recall: 0.7850 - learning_rate: 0.0010
# Epoch 2/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7613 - loss: 0.6193 - precision: 0.7931 - recall: 0.7166
# Epoch 2: val_loss improved from 0.45876 to 0.40820, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.7613 - loss: 0.6193 - precision: 0.7931 - recall: 0.7166 - val_accuracy: 0.8463 - val_loss: 0.4082 - val_precision: 0.8780 - val_recall: 0.8103 - learning_rate: 0.0010
# Epoch 3/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7857 - loss: 0.5474 - precision: 0.8169 - recall: 0.7495
# Epoch 3: val_loss improved from 0.40820 to 0.36146, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.7857 - loss: 0.5474 - precision: 0.8169 - recall: 0.7495 - val_accuracy: 0.8657 - val_loss: 0.3615 - val_precision: 0.8881 - val_recall: 0.8348 - learning_rate: 0.0010
# Epoch 4/50
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8019 - loss: 0.5065 - precision: 0.8281 - recall: 0.7670
# Epoch 4: val_loss improved from 0.36146 to 0.34549, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - accuracy: 0.8019 - loss: 0.5065 - precision: 0.8281 - recall: 0.7670 - val_accuracy: 0.8768 - val_loss: 0.3455 - val_precision: 0.8979 - val_recall: 0.8445 - learning_rate: 0.0010
# Epoch 5/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8181 - loss: 0.4697 - precision: 0.8436 - recall: 0.7880
# Epoch 5: val_loss improved from 0.34549 to 0.32048, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.8181 - loss: 0.4698 - precision: 0.8436 - recall: 0.7880 - val_accuracy: 0.8759 - val_loss: 0.3205 - val_precision: 0.9005 - val_recall: 0.8519 - learning_rate: 0.0010
# Epoch 6/50
# 1079/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8198 - loss: 0.4623 - precision: 0.8451 - recall: 0.7897
# Epoch 6: val_loss improved from 0.32048 to 0.31243, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.8198 - loss: 0.4623 - precision: 0.8451 - recall: 0.7898 - val_accuracy: 0.8851 - val_loss: 0.3124 - val_precision: 0.9074 - val_recall: 0.8639 - learning_rate: 0.0010
# Epoch 7/50
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8321 - loss: 0.4248 - precision: 0.8568 - recall: 0.8077
# Epoch 7: val_loss improved from 0.31243 to 0.30470, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - accuracy: 0.8321 - loss: 0.4248 - precision: 0.8568 - recall: 0.8077 - val_accuracy: 0.8842 - val_loss: 0.3047 - val_precision: 0.8996 - val_recall: 0.8597 - learning_rate: 0.0010
# Epoch 8/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8357 - loss: 0.4172 - precision: 0.8594 - recall: 0.8154
# Epoch 8: val_loss did not improve from 0.30470
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8357 - loss: 0.4172 - precision: 0.8594 - recall: 0.8154 - val_accuracy: 0.8874 - val_loss: 0.3123 - val_precision: 0.9091 - val_recall: 0.8629 - learning_rate: 0.0010
# Epoch 9/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8422 - loss: 0.4128 - precision: 0.8626 - recall: 0.8164
# Epoch 9: val_loss improved from 0.30470 to 0.28116, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8422 - loss: 0.4128 - precision: 0.8626 - recall: 0.8164 - val_accuracy: 0.8929 - val_loss: 0.2812 - val_precision: 0.9132 - val_recall: 0.8736 - learning_rate: 0.0010
# Epoch 10/50
# 1081/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8535 - loss: 0.3791 - precision: 0.8728 - recall: 0.8345
# Epoch 10: val_loss did not improve from 0.28116
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8535 - loss: 0.3791 - precision: 0.8728 - recall: 0.8345 - val_accuracy: 0.8925 - val_loss: 0.2833 - val_precision: 0.9110 - val_recall: 0.8786 - learning_rate: 0.0010
# Epoch 11/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8519 - loss: 0.3835 - precision: 0.8694 - recall: 0.8330
# Epoch 11: val_loss improved from 0.28116 to 0.26997, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - accuracy: 0.8519 - loss: 0.3835 - precision: 0.8694 - recall: 0.8330 - val_accuracy: 0.8962 - val_loss: 0.2700 - val_precision: 0.9096 - val_recall: 0.8874 - learning_rate: 0.0010
# Epoch 12/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8540 - loss: 0.3804 - precision: 0.8697 - recall: 0.8346
# Epoch 12: val_loss did not improve from 0.26997
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8540 - loss: 0.3804 - precision: 0.8697 - recall: 0.8346 - val_accuracy: 0.8952 - val_loss: 0.2720 - val_precision: 0.9099 - val_recall: 0.8805 - learning_rate: 0.0010
# Epoch 13/50
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8592 - loss: 0.3696 - precision: 0.8774 - recall: 0.8412
# Epoch 13: val_loss improved from 0.26997 to 0.25306, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8592 - loss: 0.3695 - precision: 0.8774 - recall: 0.8412 - val_accuracy: 0.9063 - val_loss: 0.2531 - val_precision: 0.9267 - val_recall: 0.8920 - learning_rate: 0.0010
# Epoch 14/50
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8626 - loss: 0.3453 - precision: 0.8797 - recall: 0.8438
# Epoch 14: val_loss did not improve from 0.25306
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.8626 - loss: 0.3453 - precision: 0.8797 - recall: 0.8438 - val_accuracy: 0.9036 - val_loss: 0.2542 - val_precision: 0.9147 - val_recall: 0.8902 - learning_rate: 0.0010
# Epoch 15/50
# 1079/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8636 - loss: 0.3518 - precision: 0.8805 - recall: 0.8463
# Epoch 15: val_loss did not improve from 0.25306
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8636 - loss: 0.3519 - precision: 0.8805 - recall: 0.8462 - val_accuracy: 0.9063 - val_loss: 0.2604 - val_precision: 0.9194 - val_recall: 0.8948 - learning_rate: 0.0010
# Epoch 16/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8635 - loss: 0.3525 - precision: 0.8816 - recall: 0.8474
# Epoch 16: val_loss improved from 0.25306 to 0.24862, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8635 - loss: 0.3525 - precision: 0.8816 - recall: 0.8474 - val_accuracy: 0.9063 - val_loss: 0.2486 - val_precision: 0.9201 - val_recall: 0.8929 - learning_rate: 0.0010
# Epoch 17/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8746 - loss: 0.3253 - precision: 0.8896 - recall: 0.8583
# Epoch 17: val_loss improved from 0.24862 to 0.23016, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8746 - loss: 0.3253 - precision: 0.8896 - recall: 0.8583 - val_accuracy: 0.9160 - val_loss: 0.2302 - val_precision: 0.9272 - val_recall: 0.9054 - learning_rate: 0.0010
# Epoch 18/50
# 1082/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8677 - loss: 0.3364 - precision: 0.8837 - recall: 0.8524
# Epoch 18: val_loss did not improve from 0.23016
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8677 - loss: 0.3364 - precision: 0.8837 - recall: 0.8525 - val_accuracy: 0.9109 - val_loss: 0.2393 - val_precision: 0.9225 - val_recall: 0.9008 - learning_rate: 0.0010
# Epoch 19/50
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8683 - loss: 0.3432 - precision: 0.8834 - recall: 0.8533
# Epoch 19: val_loss did not improve from 0.23016
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8683 - loss: 0.3432 - precision: 0.8834 - recall: 0.8533 - val_accuracy: 0.9105 - val_loss: 0.2378 - val_precision: 0.9250 - val_recall: 0.8999 - learning_rate: 0.0010
# Epoch 20/50
# 1081/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8721 - loss: 0.3258 - precision: 0.8881 - recall: 0.8594
# Epoch 20: val_loss did not improve from 0.23016
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.8721 - loss: 0.3258 - precision: 0.8880 - recall: 0.8594 - val_accuracy: 0.9008 - val_loss: 0.2554 - val_precision: 0.9125 - val_recall: 0.8906 - learning_rate: 0.0010
# Epoch 21/50
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8718 - loss: 0.3228 - precision: 0.8893 - recall: 0.8569
# Epoch 21: val_loss improved from 0.23016 to 0.21970, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8718 - loss: 0.3228 - precision: 0.8893 - recall: 0.8569 - val_accuracy: 0.9165 - val_loss: 0.2197 - val_precision: 0.9271 - val_recall: 0.9091 - learning_rate: 0.0010
# Epoch 22/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8762 - loss: 0.3169 - precision: 0.8914 - recall: 0.8631
# Epoch 22: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8762 - loss: 0.3169 - precision: 0.8914 - recall: 0.8631 - val_accuracy: 0.9077 - val_loss: 0.2440 - val_precision: 0.9224 - val_recall: 0.8994 - learning_rate: 0.0010
# Epoch 23/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8797 - loss: 0.3094 - precision: 0.8948 - recall: 0.8659
# Epoch 23: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8797 - loss: 0.3094 - precision: 0.8948 - recall: 0.8658 - val_accuracy: 0.9146 - val_loss: 0.2301 - val_precision: 0.9245 - val_recall: 0.9040 - learning_rate: 0.0010
# Epoch 24/50
# 1079/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8835 - loss: 0.2995 - precision: 0.8957 - recall: 0.8706
# Epoch 24: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8835 - loss: 0.2995 - precision: 0.8957 - recall: 0.8706 - val_accuracy: 0.9119 - val_loss: 0.2409 - val_precision: 0.9276 - val_recall: 0.9040 - learning_rate: 0.0010
# Epoch 25/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8865 - loss: 0.3115 - precision: 0.8964 - recall: 0.8730
# Epoch 25: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8864 - loss: 0.3115 - precision: 0.8964 - recall: 0.8730 - val_accuracy: 0.9128 - val_loss: 0.2320 - val_precision: 0.9210 - val_recall: 0.9040 - learning_rate: 0.0010
# Epoch 26/50
# 1080/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8865 - loss: 0.3055 - precision: 0.9006 - recall: 0.8722
# Epoch 26: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8865 - loss: 0.3055 - precision: 0.9006 - recall: 0.8722 - val_accuracy: 0.9100 - val_loss: 0.2368 - val_precision: 0.9233 - val_recall: 0.8999 - learning_rate: 0.0010
#
# --- FASE 2: Iniciando Fine-Tuning (Ajuste Fino) ---
# Epoch 27/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4897 - loss: 1.3781 - precision: 0.5389 - recall: 0.3993
# Epoch 27: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 162s 81ms/step - accuracy: 0.4898 - loss: 1.3779 - precision: 0.5389 - recall: 0.3993 - val_accuracy: 0.6645 - val_loss: 0.8249 - val_precision: 0.7604 - val_recall: 0.5053 - learning_rate: 1.0000e-05
# Epoch 28/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6373 - loss: 0.9315 - precision: 0.6969 - recall: 0.5532
# Epoch 28: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.6373 - loss: 0.9315 - precision: 0.6970 - recall: 0.5532 - val_accuracy: 0.7467 - val_loss: 0.6459 - val_precision: 0.8388 - val_recall: 0.6244 - learning_rate: 1.0000e-05
# Epoch 29/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7064 - loss: 0.7578 - precision: 0.7624 - recall: 0.6360
# Epoch 29: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.7064 - loss: 0.7578 - precision: 0.7625 - recall: 0.6360 - val_accuracy: 0.7923 - val_loss: 0.5538 - val_precision: 0.8683 - val_recall: 0.6844 - learning_rate: 1.0000e-05
# Epoch 30/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7467 - loss: 0.6536 - precision: 0.7966 - recall: 0.6862
# Epoch 30: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.7467 - loss: 0.6535 - precision: 0.7966 - recall: 0.6862 - val_accuracy: 0.8177 - val_loss: 0.4877 - val_precision: 0.8839 - val_recall: 0.7240 - learning_rate: 1.0000e-05
# Epoch 31/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7899 - loss: 0.5520 - precision: 0.8348 - recall: 0.7352
# Epoch 31: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.7899 - loss: 0.5520 - precision: 0.8348 - recall: 0.7352 - val_accuracy: 0.8320 - val_loss: 0.4400 - val_precision: 0.8957 - val_recall: 0.7568 - learning_rate: 1.0000e-05
# Epoch 32/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8153 - loss: 0.4889 - precision: 0.8528 - recall: 0.7708
# Epoch 32: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8153 - loss: 0.4889 - precision: 0.8528 - recall: 0.7708 - val_accuracy: 0.8551 - val_loss: 0.3959 - val_precision: 0.8977 - val_recall: 0.7813 - learning_rate: 1.0000e-05
# Epoch 33/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8352 - loss: 0.4481 - precision: 0.8716 - recall: 0.7987
# Epoch 33: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8352 - loss: 0.4481 - precision: 0.8716 - recall: 0.7987 - val_accuracy: 0.8685 - val_loss: 0.3602 - val_precision: 0.9064 - val_recall: 0.8085 - learning_rate: 1.0000e-05
# Epoch 34/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8472 - loss: 0.3977 - precision: 0.8777 - recall: 0.8121
# Epoch 34: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8472 - loss: 0.3976 - precision: 0.8777 - recall: 0.8121 - val_accuracy: 0.8699 - val_loss: 0.3305 - val_precision: 0.9008 - val_recall: 0.8210 - learning_rate: 1.0000e-05
# Epoch 35/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8695 - loss: 0.3494 - precision: 0.8940 - recall: 0.8421
# Epoch 35: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8695 - loss: 0.3494 - precision: 0.8940 - recall: 0.8421 - val_accuracy: 0.8874 - val_loss: 0.3045 - val_precision: 0.9176 - val_recall: 0.8371 - learning_rate: 1.0000e-05
# Epoch 36/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8800 - loss: 0.3120 - precision: 0.9015 - recall: 0.8560
# Epoch 36: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8800 - loss: 0.3119 - precision: 0.9015 - recall: 0.8560 - val_accuracy: 0.8888 - val_loss: 0.2780 - val_precision: 0.9209 - val_recall: 0.8546 - learning_rate: 1.0000e-05
# Epoch 37/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8935 - loss: 0.2889 - precision: 0.9122 - recall: 0.8743
# Epoch 37: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.8935 - loss: 0.2889 - precision: 0.9122 - recall: 0.8743 - val_accuracy: 0.9036 - val_loss: 0.2527 - val_precision: 0.9312 - val_recall: 0.8749 - learning_rate: 1.0000e-05
# Epoch 38/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9063 - loss: 0.2508 - precision: 0.9226 - recall: 0.8905
# Epoch 38: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.9063 - loss: 0.2508 - precision: 0.9226 - recall: 0.8905 - val_accuracy: 0.9082 - val_loss: 0.2417 - val_precision: 0.9327 - val_recall: 0.8823 - learning_rate: 1.0000e-05
# Epoch 39/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9149 - loss: 0.2307 - precision: 0.9296 - recall: 0.9010
# Epoch 39: val_loss did not improve from 0.21970
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9149 - loss: 0.2307 - precision: 0.9296 - recall: 0.9010 - val_accuracy: 0.9146 - val_loss: 0.2268 - val_precision: 0.9367 - val_recall: 0.8943 - learning_rate: 1.0000e-05
# Epoch 40/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9188 - loss: 0.2076 - precision: 0.9325 - recall: 0.9054
# Epoch 40: val_loss improved from 0.21970 to 0.20508, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9188 - loss: 0.2076 - precision: 0.9325 - recall: 0.9054 - val_accuracy: 0.9225 - val_loss: 0.2051 - val_precision: 0.9386 - val_recall: 0.9031 - learning_rate: 1.0000e-05
# Epoch 41/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9266 - loss: 0.1842 - precision: 0.9376 - recall: 0.9165
# Epoch 41: val_loss improved from 0.20508 to 0.19608, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9266 - loss: 0.1842 - precision: 0.9376 - recall: 0.9165 - val_accuracy: 0.9294 - val_loss: 0.1961 - val_precision: 0.9410 - val_recall: 0.9119 - learning_rate: 1.0000e-05
# Epoch 42/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9351 - loss: 0.1684 - precision: 0.9449 - recall: 0.9275
# Epoch 42: val_loss improved from 0.19608 to 0.17934, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9351 - loss: 0.1683 - precision: 0.9449 - recall: 0.9275 - val_accuracy: 0.9331 - val_loss: 0.1793 - val_precision: 0.9494 - val_recall: 0.9179 - learning_rate: 1.0000e-05
# Epoch 43/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9403 - loss: 0.1527 - precision: 0.9490 - recall: 0.9305
# Epoch 43: val_loss improved from 0.17934 to 0.17089, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9403 - loss: 0.1527 - precision: 0.9490 - recall: 0.9305 - val_accuracy: 0.9377 - val_loss: 0.1709 - val_precision: 0.9492 - val_recall: 0.9234 - learning_rate: 1.0000e-05
# Epoch 44/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9492 - loss: 0.1360 - precision: 0.9568 - recall: 0.9412
# Epoch 44: val_loss improved from 0.17089 to 0.16696, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9492 - loss: 0.1361 - precision: 0.9568 - recall: 0.9412 - val_accuracy: 0.9386 - val_loss: 0.1670 - val_precision: 0.9504 - val_recall: 0.9285 - learning_rate: 1.0000e-05
# Epoch 45/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9482 - loss: 0.1296 - precision: 0.9553 - recall: 0.9414
# Epoch 45: val_loss improved from 0.16696 to 0.15896, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9482 - loss: 0.1296 - precision: 0.9553 - recall: 0.9414 - val_accuracy: 0.9437 - val_loss: 0.1590 - val_precision: 0.9539 - val_recall: 0.9359 - learning_rate: 1.0000e-05
# Epoch 46/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9572 - loss: 0.1114 - precision: 0.9634 - recall: 0.9519
# Epoch 46: val_loss improved from 0.15896 to 0.15036, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9572 - loss: 0.1114 - precision: 0.9634 - recall: 0.9519 - val_accuracy: 0.9492 - val_loss: 0.1504 - val_precision: 0.9564 - val_recall: 0.9419 - learning_rate: 1.0000e-05
# Epoch 47/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9591 - loss: 0.1076 - precision: 0.9653 - recall: 0.9541
# Epoch 47: val_loss improved from 0.15036 to 0.14049, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9591 - loss: 0.1075 - precision: 0.9653 - recall: 0.9541 - val_accuracy: 0.9511 - val_loss: 0.1405 - val_precision: 0.9583 - val_recall: 0.9446 - learning_rate: 1.0000e-05
# Epoch 48/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9646 - loss: 0.0937 - precision: 0.9706 - recall: 0.9600
# Epoch 48: val_loss improved from 0.14049 to 0.14047, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9646 - loss: 0.0937 - precision: 0.9706 - recall: 0.9600 - val_accuracy: 0.9515 - val_loss: 0.1405 - val_precision: 0.9593 - val_recall: 0.9451 - learning_rate: 1.0000e-05
# Epoch 49/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9650 - loss: 0.0893 - precision: 0.9696 - recall: 0.9617
# Epoch 49: val_loss did not improve from 0.14047
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9650 - loss: 0.0893 - precision: 0.9696 - recall: 0.9617 - val_accuracy: 0.9520 - val_loss: 0.1451 - val_precision: 0.9583 - val_recall: 0.9446 - learning_rate: 1.0000e-05
# Epoch 50/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9718 - loss: 0.0780 - precision: 0.9760 - recall: 0.9677
# Epoch 50: val_loss improved from 0.14047 to 0.13042, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9718 - loss: 0.0780 - precision: 0.9760 - recall: 0.9677 - val_accuracy: 0.9548 - val_loss: 0.1304 - val_precision: 0.9595 - val_recall: 0.9502 - learning_rate: 1.0000e-05
# Epoch 51/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9737 - loss: 0.0708 - precision: 0.9771 - recall: 0.9703
# Epoch 51: val_loss improved from 0.13042 to 0.12110, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 35ms/step - accuracy: 0.9737 - loss: 0.0708 - precision: 0.9771 - recall: 0.9703 - val_accuracy: 0.9603 - val_loss: 0.1211 - val_precision: 0.9642 - val_recall: 0.9566 - learning_rate: 1.0000e-05
# Epoch 52/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9720 - loss: 0.0771 - precision: 0.9749 - recall: 0.9698
# Epoch 52: val_loss did not improve from 0.12110
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 34ms/step - accuracy: 0.9720 - loss: 0.0771 - precision: 0.9749 - recall: 0.9698 - val_accuracy: 0.9608 - val_loss: 0.1260 - val_precision: 0.9642 - val_recall: 0.9580 - learning_rate: 1.0000e-05
# Epoch 53/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9785 - loss: 0.0613 - precision: 0.9810 - recall: 0.9757
# Epoch 53: val_loss did not improve from 0.12110
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9785 - loss: 0.0613 - precision: 0.9810 - recall: 0.9757 - val_accuracy: 0.9585 - val_loss: 0.1248 - val_precision: 0.9623 - val_recall: 0.9548 - learning_rate: 1.0000e-05
# Epoch 54/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9787 - loss: 0.0571 - precision: 0.9808 - recall: 0.9767
# Epoch 54: val_loss improved from 0.12110 to 0.11457, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9787 - loss: 0.0571 - precision: 0.9808 - recall: 0.9767 - val_accuracy: 0.9645 - val_loss: 0.1146 - val_precision: 0.9666 - val_recall: 0.9603 - learning_rate: 1.0000e-05
# Epoch 55/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9825 - loss: 0.0515 - precision: 0.9844 - recall: 0.9804
# Epoch 55: val_loss did not improve from 0.11457
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9825 - loss: 0.0515 - precision: 0.9844 - recall: 0.9804 - val_accuracy: 0.9640 - val_loss: 0.1154 - val_precision: 0.9666 - val_recall: 0.9603 - learning_rate: 1.0000e-05
# Epoch 56/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9817 - loss: 0.0536 - precision: 0.9834 - recall: 0.9801
# Epoch 56: val_loss improved from 0.11457 to 0.11273, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9817 - loss: 0.0536 - precision: 0.9834 - recall: 0.9801 - val_accuracy: 0.9649 - val_loss: 0.1127 - val_precision: 0.9690 - val_recall: 0.9649 - learning_rate: 1.0000e-05
# Epoch 57/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9830 - loss: 0.0469 - precision: 0.9855 - recall: 0.9809
# Epoch 57: val_loss improved from 0.11273 to 0.11120, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9830 - loss: 0.0469 - precision: 0.9855 - recall: 0.9809 - val_accuracy: 0.9677 - val_loss: 0.1112 - val_precision: 0.9689 - val_recall: 0.9645 - learning_rate: 1.0000e-05
# Epoch 58/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9871 - loss: 0.0397 - precision: 0.9878 - recall: 0.9849
# Epoch 58: val_loss improved from 0.11120 to 0.10903, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9871 - loss: 0.0397 - precision: 0.9878 - recall: 0.9849 - val_accuracy: 0.9705 - val_loss: 0.1090 - val_precision: 0.9717 - val_recall: 0.9663 - learning_rate: 1.0000e-05
# Epoch 59/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9873 - loss: 0.0368 - precision: 0.9884 - recall: 0.9859
# Epoch 59: val_loss improved from 0.10903 to 0.10847, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9873 - loss: 0.0368 - precision: 0.9884 - recall: 0.9859 - val_accuracy: 0.9682 - val_loss: 0.1085 - val_precision: 0.9694 - val_recall: 0.9663 - learning_rate: 1.0000e-05
# Epoch 60/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9870 - loss: 0.0381 - precision: 0.9891 - recall: 0.9861
# Epoch 60: val_loss improved from 0.10847 to 0.10142, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 38s 35ms/step - accuracy: 0.9870 - loss: 0.0381 - precision: 0.9891 - recall: 0.9862 - val_accuracy: 0.9686 - val_loss: 0.1014 - val_precision: 0.9694 - val_recall: 0.9659 - learning_rate: 1.0000e-05
# Epoch 61/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9874 - loss: 0.0381 - precision: 0.9887 - recall: 0.9862
# Epoch 61: val_loss did not improve from 0.10142
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9874 - loss: 0.0381 - precision: 0.9887 - recall: 0.9862 - val_accuracy: 0.9719 - val_loss: 0.1047 - val_precision: 0.9722 - val_recall: 0.9700 - learning_rate: 1.0000e-05
# Epoch 62/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9877 - loss: 0.0332 - precision: 0.9885 - recall: 0.9871
# Epoch 62: val_loss improved from 0.10142 to 0.09100, saving model to /content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9877 - loss: 0.0332 - precision: 0.9885 - recall: 0.9871 - val_accuracy: 0.9742 - val_loss: 0.0910 - val_precision: 0.9750 - val_recall: 0.9737 - learning_rate: 1.0000e-05
# Epoch 63/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9907 - loss: 0.0279 - precision: 0.9912 - recall: 0.9896
# Epoch 63: val_loss did not improve from 0.09100
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 37s 34ms/step - accuracy: 0.9907 - loss: 0.0279 - precision: 0.9912 - recall: 0.9896 - val_accuracy: 0.9714 - val_loss: 0.0976 - val_precision: 0.9727 - val_recall: 0.9695 - learning_rate: 1.0000e-05
# Epoch 64/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9901 - loss: 0.0273 - precision: 0.9906 - recall: 0.9893
# Epoch 64: val_loss did not improve from 0.09100
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9901 - loss: 0.0273 - precision: 0.9905 - recall: 0.9893 - val_accuracy: 0.9705 - val_loss: 0.0940 - val_precision: 0.9727 - val_recall: 0.9695 - learning_rate: 1.0000e-05
# Epoch 65/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9894 - loss: 0.0287 - precision: 0.9907 - recall: 0.9891
# Epoch 65: val_loss did not improve from 0.09100
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 35s 33ms/step - accuracy: 0.9894 - loss: 0.0287 - precision: 0.9907 - recall: 0.9891 - val_accuracy: 0.9705 - val_loss: 0.0992 - val_precision: 0.9713 - val_recall: 0.9695 - learning_rate: 1.0000e-05
# Epoch 66/70
# 1083/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9913 - loss: 0.0283 - precision: 0.9920 - recall: 0.9900
# Epoch 66: val_loss did not improve from 0.09100
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9913 - loss: 0.0283 - precision: 0.9920 - recall: 0.9900 - val_accuracy: 0.9695 - val_loss: 0.1089 - val_precision: 0.9704 - val_recall: 0.9686 - learning_rate: 1.0000e-05
# Epoch 67/70
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9922 - loss: 0.0252 - precision: 0.9926 - recall: 0.9917
# Epoch 67: val_loss did not improve from 0.09100
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 36s 33ms/step - accuracy: 0.9922 - loss: 0.0252 - precision: 0.9926 - recall: 0.9917 - val_accuracy: 0.9695 - val_loss: 0.1060 - val_precision: 0.9704 - val_recall: 0.9691 - learning_rate: 1.0000e-05
#
# Iniciando plotagem e avaliação...
# Avaliação do modelo final no conjunto de teste:
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 18s 131ms/step - accuracy: 0.9686 - loss: 0.1261 - precision: 0.9719 - recall: 0.9668
# Loss no teste: 0.1755
# Acurácia no teste: 0.9654
# Precisão no teste: 0.9671
# Recall no teste: 0.9626
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 14s 53ms/step
# F1-score no teste: 0.9653
# Pronto para gerar matriz de confusão

# %% [markdown]
# # GERAR MATRIZ DE CONFUSÃO - USAR CPU

# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import kagglehub

# PASSOS 1 A 5 SÃO NECESSÁRIOS POIS O KERNEL LIMPOU
# 1. Re-download do dataset
path = kagglehub.dataset_download("mohammadhossein77/brain-tumors-dataset")
print("Kaggle dataset re-downloaded to:", path)

# 2. Carregar dados do Drive
test_paths = np.load('/content/drive/MyDrive/Projeto/test_paths.npy')
test_labels = np.load('/content/drive/MyDrive/Projeto/test_labels.npy')

# 3. Arrumar os paths no test_paths para coincidir com a nova localização do dataset
old_base_path = '/kaggle/input/brain-tumors-dataset'
corrected_test_paths = np.array([p.replace(old_base_path, path) for p in test_paths])
test_paths = corrected_test_paths

# 4. Carregar o modelo
model = keras.models.load_model('/content/drive/MyDrive/Projeto/modelos_salvos/TLSeg_128_6.keras')

# 5. Re-definir configurações básicas
IMAGE_SIZE = (128, 128)

def segment_image_cv(image_tensor):
    img = image_tensor.numpy().astype(np.uint8)
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Se a imagem vier com shape (1, 128, 128, 3), remove o 1
    if len(img.shape) == 4:
        img = np.squeeze(img, axis=0)

    # Conversão para tons de cinza
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    blurred = cv2.GaussianBlur(gray, (7, 7), 0)

    # Otsu Thresholding
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Aplica a máscara
    segmented = cv2.bitwise_and(img, img, mask=thresh)

    return segmented.astype(np.float32)

def create_tf_dataset(image_paths, labels, batch_size=32):
    def load_image(path, label):
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, IMAGE_SIZE)
        [img,] = tf.py_function(segment_image_cv, [img], [tf.float32])
        img.set_shape((IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        return img, tf.one_hot(label, 4)
    return tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(load_image).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Gerar matriz de confusão
test_ds = create_tf_dataset(test_paths, test_labels)
y_pred = np.argmax(model.predict(test_ds), axis=1)

cm = confusion_matrix(test_labels, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Glioma', 'Meningioma', 'Pituitary'],
            yticklabels=['Normal', 'Glioma', 'Meningioma', 'Pituitary'])
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using Colab cache for faster access to the 'brain-tumors-dataset' dataset.
# Kaggle dataset re-downloaded to: /kaggle/input/brain-tumors-dataset
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 556s 8s/step

# %%
model.summary()
# Out:
# Model: "EfficientNet_TransferLearning"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 4, 4, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,568,361 (47.94 MB)
#  Trainable params: 4,174,592 (15.92 MB)
#  Non-trainable params: 44,583 (174.16 KB)
#  Optimizer params: 8,349,186 (31.85 MB)
